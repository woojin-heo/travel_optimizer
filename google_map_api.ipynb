# %%
import requests
import pandas as pd
from tqdm import tqdm  # tqdm 라이브러리 추가
import math

api_key=''

def split_locations(locations, max_locations=10):
    """
    Split locations into smaller groups to avoid exceeding API URL limits.
    
    Args:
        locations (list): List of location names.
        max_locations (int): Maximum number of locations per group.
    
    Returns:
        list: List of grouped locations.
    """
    return [locations[i:i + max_locations] for i in range(0, len(locations), max_locations)]

def calculate_distances(locations, api_key, max_locations=10):
    """
    Calculate distances between all given locations using Google Distance Matrix API.
    
    Args:
        locations (list): List of location names.
        api_key (str): Google Maps API key.
        max_locations (int): Maximum number of locations per group.
        
    Returns:
        pandas.DataFrame: Distance matrix with travel times.
    """
    # Prepare empty matrices
    n = len(locations)
    distance_matrix = [["" for _ in range(n)] for _ in range(n)]
    time_matrix = [["" for _ in range(n)] for _ in range(n)]
    
    # Split locations into manageable groups
    groups = split_locations(locations, max_locations)
    total_iterations = len(groups) ** 2  # total calcuation time

    # Loop through each origin group
    with tqdm(total=total_iterations, desc="Processing Groups") as pbar:
        for i, origins_group in enumerate(groups):
            for j, destinations_group in enumerate(groups):
                # Prepare API endpoint and parameters
                endpoint = "https://maps.googleapis.com/maps/api/distancematrix/json"
                params = {
                    "origins": "|".join(origins_group),
                    "destinations": "|".join(destinations_group),
                    "key": api_key,
                    "units": "metric",
                }
                
                # API call
                try:
                    response = requests.get(endpoint, params=params)
                    response.raise_for_status()  # Raise HTTPError for bad responses
                    data = response.json()
                    
                    # Check for valid response
                    if data.get("status") != "OK":
                        # print(f"Warning: API response error - {data.get('error_message', 'Unknown error')}")
                        continue
                    
                    # Extract distances and durations
                    for oi, row in enumerate(data.get("rows", [])):
                        for di, elem in enumerate(row.get("elements", [])):
                            distance = elem.get("distance", {}).get("text", "")
                            duration = elem.get("duration", {}).get("text", "")
                            origin_index = i * max_locations + oi
                            destination_index = j * max_locations + di
                            if origin_index < n and destination_index < n:
                                distance_matrix[origin_index][destination_index] = distance
                                time_matrix[origin_index][destination_index] = duration
                except Exception as e:
                    # print(f"Error during API call for group ({i}, {j}): {str(e)}")
                    continue
                finally:
                    pbar.update(1)  # Update progress bar for each iteration

    # Create DataFrames
    distance_df = pd.DataFrame(distance_matrix, index=locations, columns=locations)
    time_df = pd.DataFrame(time_matrix, index=locations, columns=locations)
    
    return distance_df, time_df

# %%
data = pd.read_excel('Dataset.xlsx')
locations = data['Name'].tolist()
len(locations)
# Out:
# 141

# %%
# Calculate distances and durations
distance_df, time_df = calculate_distances(locations, api_key, max_locations=5)

print("\nTime Matrix (in hours/minutes):")
display(time_df)
# Out:
# Processing Groups: 100%|██████████| 841/841 [01:40<00:00,  8.36it/s]
# Time Matrix (in hours/minutes):
#                                                    60 Bukit Timah Rd, B1-02, Singapore 229900  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                              1 min
# 300 Tiong Bahru Rd, Singapore 168731                                                  14 mins
# 26 Bussorah St, Singapore 199444                                                       9 mins
# 261 Victoria St, Singapore 189876                                                      5 mins
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                   11 mins
# 300 Tiong Bahru Rd, Singapore 168731                                         12 mins
# 26 Bussorah St, Singapore 199444                                              9 mins
# 261 Victoria St, Singapore 189876                                             8 mins
# 10, Telok Blangah Green, 109178                                              15 mins
# ...                                                                              ...
# Lai Kee Pau & Dim Sum - Clementi                                             23 mins
# 200 Victoria St, B1 04A, Singapore 188021                                    10 mins
# 36 College Ave E, North Tower, Singapore 138600                              18 mins
# 10 Bayfront Ave, Singapore 018956                                              1 min
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                           19 mins
#
#                                                    65 Airport Blvd., Level 2 Terminal 3, Singapore 819663
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                                    19 mins
# 300 Tiong Bahru Rd, Singapore 168731                                                          22 mins
# 26 Bussorah St, Singapore 199444                                                              18 mins
# 261 Victoria St, Singapore 189876                                                             17 mins
# 10, Telok Blangah Green, 109178                                                               25 mins
# ...                                                                                               ...
# Lai Kee Pau & Dim Sum - Clementi                                                              26 mins
# 200 Victoria St, B1 04A, Singapore 188021                                                     19 mins
# 36 College Ave E, North Tower, Singapore 138600                                               27 mins
# 10 Bayfront Ave, Singapore 018956                                                             17 mins
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                                              1 min
#
# [141 rows x 141 columns]

# %%
time_df.to_excel('./distance_v4.xlsx')

# %%
# hour to min 
def time_to_minutes(value):
    if isinstance(value, str):
        minutes = 0
        try:
            # Days -> min
            if "day" in value:
                days_part = value.split("day")[0].strip()
                minutes += int(days_part) * 24 * 60  # day -> min
                value = " ".join(value.split("day")[1:]).strip()
            
            # Hours -> min
            if "hour" in value:
                hours_part = value.split("hour")[0].strip()
                minutes += int(hours_part) * 60  # hour -> min
                value = " ".join(value.split("hour")[1:]).strip()
            
            # Minutes 
            if "min" in value:
                minutes_part = value.split("min")[0].strip()
                if minutes_part.isdigit():
                    minutes += int(minutes_part)
        except Exception as e:
            print(f"Error processing value '{value}': {e}")
            return ''
        return minutes
    return ''  # N/A -> 0

time_df_minutes = time_df.applymap(time_to_minutes)
# Out:
# /var/folders/pw/_ml9mkrn07v5x0fngqp4qhg00000gn/T/ipykernel_15531/2375099597.py:29: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   time_df_minutes = time_df.applymap(time_to_minutes)

# %%
time_df_minutes
# Out:
#                                                     60 Bukit Timah Rd, B1-02, Singapore 229900  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                                   1
# 300 Tiong Bahru Rd, Singapore 168731                                                        14
# 26 Bussorah St, Singapore 199444                                                             9
# 261 Victoria St, Singapore 189876                                                            5
# 10, Telok Blangah Green, 109178                                                             18
# ...                                                                                        ...
# Lai Kee Pau & Dim Sum - Clementi                                                            17
# 200 Victoria St, B1 04A, Singapore 188021                                                    8
# 36 College Ave E, North Tower, Singapore 138600                                             21
# 10 Bayfront Ave, Singapore 018956                                                           11
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                                          21
#
#                                                     300 Tiong Bahru Rd, Singapore 168731  \
#
#                                                     Wings of Time  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                     21
# 300 Tiong Bahru Rd, Singapore 168731                           13
# 26 Bussorah St, Singapore 199444                               20
# 261 Victoria St, Singapore 189876                              19
# 10, Telok Blangah Green, 109178                                14
# ...                                                           ...
# Lai Kee Pau & Dim Sum - Clementi                               26
# 200 Victoria St, B1 04A, Singapore 188021                      21
# 36 College Ave E, North Tower, Singapore 138600                20
# 10 Bayfront Ave, Singapore 018956                              15
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...             27
#
#                                                     Night Safari Singapore  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                              28
# 300 Tiong Bahru Rd, Singapore 168731                                    29
# 26 Bussorah St, Singapore 199444                                        30
# 261 Victoria St, Singapore 189876                                       27
# 10, Telok Blangah Green, 109178                                         30
# ...                                                                    ...
# Lai Kee Pau & Dim Sum - Clementi                                        16
# 200 Victoria St, B1 04A, Singapore 188021                               31
# 36 College Ave E, North Tower, Singapore 138600                         25
# 10 Bayfront Ave, Singapore 018956                                       30
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                      30
#
#                                                     Marina Bay Sands Skypark Observation Deck  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                                 12
# 300 Tiong Bahru Rd, Singapore 168731                                                       13
# 26 Bussorah St, Singapore 199444                                                            9
# 261 Victoria St, Singapore 189876                                                          10
# 10, Telok Blangah Green, 109178                                                            16
# ...                                                                                       ...
# Lai Kee Pau & Dim Sum - Clementi                                                           22
# 200 Victoria St, B1 04A, Singapore 188021                                                   8
# 36 College Ave E, North Tower, Singapore 138600                                            19
# 10 Bayfront Ave, Singapore 018956                                                           4
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                                         19
#
#                                                     Singapore Cable Car  ...  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                           19  ...
# 300 Tiong Bahru Rd, Singapore 168731                                  9  ...
# 26 Bussorah St, Singapore 199444                                     18  ...
# 261 Victoria St, Singapore 189876                                    17  ...
# 10, Telok Blangah Green, 109178                                      10  ...
# ...                                                                 ...  ...
# Lai Kee Pau & Dim Sum - Clementi                                     23  ...
# 200 Victoria St, B1 04A, Singapore 188021                            19  ...
# 36 College Ave E, North Tower, Singapore 138600                      16  ...
# 10 Bayfront Ave, Singapore 018956                                    14  ...
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                   25  ...
#
#                                                     119 Owen Rd, Singapore 218924  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                      3
# 300 Tiong Bahru Rd, Singapore 168731                                           13
# 26 Bussorah St, Singapore 199444                                               11
# 261 Victoria St, Singapore 189876                                               7
# 10, Telok Blangah Green, 109178                                                17
# ...                                                                           ...
# Lai Kee Pau & Dim Sum - Clementi                                               19
# 200 Victoria St, B1 04A, Singapore 188021                                      11
# 36 College Ave E, North Tower, Singapore 138600                                19
# 10 Bayfront Ave, Singapore 018956                                              13
# ...                                                                              ...
# Lai Kee Pau & Dim Sum - Clementi                                                   1
# 200 Victoria St, B1 04A, Singapore 188021                                         22
# 36 College Ave E, North Tower, Singapore 138600                                   11
# 10 Bayfront Ave, Singapore 018956                                                 23
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                                29
#
#                                                     200 Victoria St, B1 04A, Singapore 188021  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                                  6
# 300 Tiong Bahru Rd, Singapore 168731                                                       13
# 26 Bussorah St, Singapore 199444                                                            5
# 261 Victoria St, Singapore 189876                                                           4
# 10, Telok Blangah Green, 109178                                                            17
# ...                                                                                       ...
# Lai Kee Pau & Dim Sum - Clementi                                                           22
# 200 Victoria St, B1 04A, Singapore 188021                                                   1
# 36 College Ave E, North Tower, Singapore 138600                                            19
# 10 Bayfront Ave, Singapore 018956                                                           7
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                                         18
#
#                                                     36 College Ave E, North Tower, Singapore 138600  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                                       21
# 300 Tiong Bahru Rd, Singapore 168731                                                             13
# 26 Bussorah St, Singapore 199444                                                                 23
# 261 Victoria St, Singapore 189876                                                                22
# 10, Telok Blangah Green, 109178                                                                  14
# ...                                                                                             ...
# Lai Kee Pau & Dim Sum - Clementi                                                                 12
# 200 Victoria St, B1 04A, Singapore 188021                                                        21
# 36 College Ave E, North Tower, Singapore 138600                                                   1
# 10 Bayfront Ave, Singapore 018956                                                                18
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                                               30
#
#                                                     10 Bayfront Ave, Singapore 018956  \
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                         11
# 300 Tiong Bahru Rd, Singapore 168731                                               12
# 26 Bussorah St, Singapore 199444                                                    9
# 261 Victoria St, Singapore 189876                                                   8
# 10, Telok Blangah Green, 109178                                                    15
# ...                                                                               ...
# Lai Kee Pau & Dim Sum - Clementi                                                   23
# 200 Victoria St, B1 04A, Singapore 188021                                          10
# 36 College Ave E, North Tower, Singapore 138600                                    18
# 10 Bayfront Ave, Singapore 018956                                                   1
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                                 19
#
#                                                     65 Airport Blvd., Level 2 Terminal 3, Singapore 819663
# 60 Bukit Timah Rd, B1-02, Singapore 229900                                                         19
# 300 Tiong Bahru Rd, Singapore 168731                                                               22
# 26 Bussorah St, Singapore 199444                                                                   18
# 261 Victoria St, Singapore 189876                                                                  17
# 10, Telok Blangah Green, 109178                                                                    25
# ...                                                                                               ...
# Lai Kee Pau & Dim Sum - Clementi                                                                   26
# 200 Victoria St, B1 04A, Singapore 188021                                                          19
# 36 College Ave E, North Tower, Singapore 138600                                                    27
# 10 Bayfront Ave, Singapore 018956                                                                  17
# 65 Airport Blvd., Level 2 Terminal 3, Singapore...                                                  1
#
# [141 rows x 141 columns]

# %%
time_df_minutes.to_excel('./distance_in_min_v4.xlsx')
